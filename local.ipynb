# %%
# !tar chvzf notebook.tar.gz --exclude notebook.tar.gz *
# Out:
# Assignment 1.ipynb
# Assignment 2.ipynb
# Assignment 3.ipynb
# Assignment 4.ipynb
# Classifier Visualization.ipynb
# Module 1.ipynb
# Module 2.ipynb
# Module 3.ipynb
# Module 4.ipynb
# Unsupervised Learning.ipynb
# __pycache__/
# __pycache__/adspy_shared_utilities.cpython-35.pyc
# __pycache__/adspy_shared_utilities.cpython-36.pyc
# adspy_shared_utilities.py
# adspy_temp.dot
# fraud_data.csv
# fruit_data_with_colors.txt
# local.ipynb
# mushrooms.csv
# readonly/
# readonly/addresses.csv
# readonly/train.csv
# readonly/Module 2.ipynb
# readonly/Assignment 3.ipynb
# readonly/Module 4.ipynb
# readonly/Assignment 1.ipynb
# readonly/test.csv
# readonly/.ipynb_checkpoints/
# readonly/.ipynb_checkpoints/Assignment 2-checkpoint.ipynb
# readonly/.ipynb_checkpoints/Assignment 4-checkpoint.ipynb
# readonly/.ipynb_checkpoints/Unsupervised Learning-checkpoint.ipynb
# readonly/.ipynb_checkpoints/Assignment 3-checkpoint.ipynb
# readonly/.ipynb_checkpoints/Assignment 1-checkpoint.ipynb
# ...

# %%
help('modules')
# Out:
# Please wait a moment while I gather a list of all available modules...
# /opt/conda/lib/python3.6/site-packages/IPython/kernel/__init__.py:13: ShimWarning: The `IPython.kernel` package has been deprecated. You should import from ipykernel or jupyter_client instead.
#   "You should import from ipykernel or jupyter_client instead.", ShimWarning)
# /opt/conda/lib/python3.6/site-packages/bokeh/util/deprecation.py:34: BokehDeprecationWarning:
# The bokeh.charts API has moved to a separate 'bkcharts' package.
#
# This compatibility shim will remain until Bokeh 1.0 is released.
# After that, if you want to use this API you will have to install
# the bkcharts package explicitly.
#
#   warn(message)
# ...
